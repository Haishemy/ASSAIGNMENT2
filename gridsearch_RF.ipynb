# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid= {
    'criterion': ['squared_error','absolute_error','friedman_mse','poisson'],
            'max_features':['sqrt','log2', None]
}
grid= GridSearchCV(RandomForestRegressor(), param_grid, refit=True, verbose=3, n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# C:\Users\haish\anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['sqrt', 'log2', None]},
#              verbose=3)

# %%
re=grid.cv_results_
print("the best r2 value is:{}".format(grid.best_params_))
# Out:
# the best r2 value is:{'criterion': 'poisson', 'max_features': 'log2'}

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        1.022060      0.584047         0.047825        0.033258
# 1        0.795327      0.139621         0.021357        0.010085
# 2        1.085005      0.344150         0.032905        0.025581
# 3        3.628878      1.661074         0.053182        0.053050
# 4        5.435484      2.359828         0.113396        0.121530
# 5        7.798116      2.181541         0.168670        0.195706
# 6        1.956522      0.941152         0.082741        0.077272
# 7        2.006275      1.718647         0.023856        0.006971
# 8        2.985549      0.800785         0.057722        0.062654
# 9        1.910573      1.016200         0.089776        0.088643
# 10       1.530548      0.901342         0.050572        0.049408
# 11       2.030302      0.856507         0.051568        0.056858
#
#    param_criterion param_max_features  \
# 0    squared_error               sqrt
# 1    squared_error               log2
# 2    squared_error               None
# 3   absolute_error               sqrt
# 4   absolute_error               log2
# 5   absolute_error               None
# 6     friedman_mse               sqrt
# 7     friedman_mse               log2
# 8     friedman_mse               None
# 9          poisson               sqrt
# 10         poisson               log2
# 11         poisson               None
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.852974
# 1   {'criterion': 'squared_error', 'max_features':...           0.856483
# 2   {'criterion': 'squared_error', 'max_features':...           0.847489
# 3   {'criterion': 'absolute_error', 'max_features'...           0.858756
# 4   {'criterion': 'absolute_error', 'max_features'...           0.859057
# 5   {'criterion': 'absolute_error', 'max_features'...           0.837682
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.857994
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.859322
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.850024
# 9    {'criterion': 'poisson', 'max_features': 'sqrt'}           0.856906
# 10   {'criterion': 'poisson', 'max_features': 'log2'}           0.861582
# 11     {'criterion': 'poisson', 'max_features': None}           0.847079
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.777264           0.857429           0.830469
# 1            0.781659           0.864559           0.826698
# 2            0.765591           0.857059           0.818604
# 3            0.776816           0.857357           0.829027
# 4            0.778965           0.849704           0.826107
# 5            0.763567           0.843505           0.823639
# 6            0.778432           0.858236           0.829000
# 7            0.779763           0.862943           0.828752
# 8            0.778431           0.860090           0.817114
# 9            0.775052           0.862315           0.826419
# 10           0.776972           0.864223           0.828979
# 11           0.770857           0.859194           0.818542
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.843093         0.832246        0.029009                6
# 1            0.842212         0.834322        0.029323                3
# 2            0.833991         0.824547        0.032199               11
# 3            0.842510         0.832893        0.030065                4
# 4            0.847016         0.832170        0.028700                8
# 5            0.834744         0.820627        0.029252               12
# 6            0.840561         0.832845        0.029367                5
# 7            0.841198         0.834396        0.029997                2
# 8            0.838797         0.828891        0.028993                9
# 9            0.840534         0.832245        0.031260                7
# 10           0.840862         0.834524        0.031615                1
# 11           0.839021         0.826939        0.031009               10

# %%
import pickle
filename="finalized_model_RF.sav"
pickle.dump(regressor,open(filename,'wb'))
loaded_model=pickle.load(open("finalized_model_DT.sav",'rb'))
result=loaded_model.predict([[33,22,3,1,0]])

# %%
result
